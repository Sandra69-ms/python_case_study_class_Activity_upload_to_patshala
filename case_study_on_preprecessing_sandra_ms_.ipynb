# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandra69-ms/python_case_study_class_Activity_upload_to_patshala/blob/main/case_study_on_preprecessing_sandra_ms_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_wine = pd.read_csv("/content/winequality-red.csv")
data_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data_wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data_wine.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data_wine.shape
# Out:
# (1599, 12)

# %%
data_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data_wine.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %% [markdown]
# data Cleaning

# %%
# Remove duplicates if any
data_wine = data_wine.drop_duplicates()

# %%
data_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# outlier detection

# %%
import seaborn as sns

# %%
for i , col in enumerate(data_wine.columns):
    plt.figure(figsize=(8,8))
    sns.histplot(data=data_wine ,x=col ,kde=True)
    plt.title(col)
    plt.show()

# %%
from scipy.stats import probplot
for i , col in enumerate(data_wine.columns):
    plt.figure(figsize=(8,8))
    probplot(data_wine[col] , plot=plt)
    plt.title(col)
    plt.show()

# %%
for i in data_wine:
  plt.figure(figsize=(5,5))
  plt.boxplot(data_wine[i])
  plt.title(i)

# %%
correlation = data_wine.corr()
correlation
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# Handiling the outlier

# %%
data_wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
from scipy.stats.mstats import winsorize

# %%
data_wine.loc[:,'fixed acidity'] = winsorize(data_wine['fixed acidity'],limits=(.05,.0))

# %%
data_wine.loc[:, "volatile acidity"] = winsorize(data_wine['volatile acidity'],limits=(.05,0))

# %%
data_wine.loc[:,'citric acid'] = winsorize(data_wine['citric acid'],limits=(0.05,0))

# %%
data_wine.loc[:,'residual sugar'] = winsorize(data_wine['residual sugar'],limits=(0.25,0))

# %%
data_wine.loc[:,'chlorides'] = winsorize(data_wine['chlorides'],limits=(0.20,0.10))

# %%
data_wine.loc[:, 'free sulfur dioxide'] = winsorize(data_wine['free sulfur dioxide'],limits=(0.10,0))

# %%
data_wine.loc[:,'total sulfur dioxide'] = winsorize(data_wine['total sulfur dioxide'],limits=(0.10,0))

# %%
data_wine.loc[:,'density'] = winsorize(data_wine['density'],limits=(0.10,0.10))

# %%
data_wine.loc[:,'pH']=winsorize(data_wine['pH'],limits=(.20,0.10))

# %%
data_wine.loc[:,'sulphates'] = winsorize(data_wine['sulphates'],limits= (0.25,0.0))

# %%
data_wine.loc[:,'alcohol'] = winsorize(data_wine['alcohol'],limits=(0.05,0))

# %%
data_wine.loc[:,'quality'] =winsorize(data_wine['quality'],limits=(0.05,0.05))

# %% [markdown]
#  # scalling

# %%
data_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.132653             0.700         0.00        0.000000      0.076
# 1          0.173469             0.880         0.00        0.051471      0.098
# 2          0.173469             0.760         0.04        0.029412      0.092
# 3          0.520408             0.280         0.56        0.000000      0.075
# 5          0.132653             0.660         0.00        0.000000      0.075
# ...             ...               ...          ...             ...        ...
# 1593       0.071429             0.620         0.08        0.000000      0.068
# 1594       0.010204             0.600         0.08        0.007353      0.090
# 1595       0.000000             0.550         0.10        0.022059      0.067
# 1597       0.000000             0.645         0.12        0.007353      0.075
# 1598       0.000000             0.310         0.47        0.125000      0.067
#
# ...

# %%
from scipy.stats import skew
from sklearn.preprocessing import MinMaxScaler ,StandardScaler
minmax_scale = MinMaxScaler()
std_scale =StandardScaler()

# %%
skewness=data_wine['fixed acidity'].skew
skewness()
# Out:
# np.float64(1.0798002240732523)

# %%
data_wine.loc[:,'fixed acidity'] = minmax_scale.fit_transform(data_wine[['fixed acidity']])

# %%
skewness = data_wine['free sulfur dioxide'].skew
skewness()
# Out:
# np.float64(1.2735734693221903)

# %%
data_wine.loc[:,'free sulfur dioxide'] = minmax_scale.fit_transform(data_wine[['free sulfur dioxide']])

# %%
skewness=data_wine['total sulfur dioxide'].skew
skewness()
# Out:
# np.float64(1.588553791666575)

# %%
data_wine.loc[:,'total sulfur dioxide'] = minmax_scale.fit_transform(data_wine[['total sulfur dioxide']])

# %%
skewness=data_wine['alcohol'].skew
skewness()
# Out:
# np.float64(0.8991656168529012)

# %%
data_wine.loc[:,'alcohol'] = minmax_scale.fit_transform(data_wine[['alcohol']])

# %%
skewness = data_wine['residual sugar'].skew
skewness()
# Out:
# np.float64(4.830622571228652)

# %%
data_wine.loc[:,'residual sugar'] = minmax_scale.fit_transform(data_wine[['residual sugar']])

# %%
skewness = data_wine['pH'].skew
skewness()
# Out:
# np.float64(0.3106945630719519)

# %%
data_wine.loc[:,'pH'] = std_scale.fit_transform(data_wine[['pH']])

# %%
skewness=data_wine['quality'].skew
skewness()
# Out:
# np.float64(0.5749418683844707)

# %%
data_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.132653             0.700         0.00        0.000000      0.076
# 1          0.173469             0.880         0.00        0.051471      0.098
# 2          0.173469             0.760         0.04        0.029412      0.092
# 3          0.520408             0.280         0.56        0.000000      0.075
# 5          0.132653             0.660         0.00        0.000000      0.075
# ...             ...               ...          ...             ...        ...
# 1593       0.071429             0.620         0.08        0.000000      0.068
# 1594       0.010204             0.600         0.08        0.007353      0.090
# 1595       0.000000             0.550         0.10        0.022059      0.067
# 1597       0.000000             0.645         0.12        0.007353      0.075
# 1598       0.000000             0.310         0.47        0.125000      0.067
#
# ...

# %% [markdown]
# # model fitting

# %%
x = data_wine.drop('quality', axis=1)
y = data_wine['quality']

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.132653             0.700         0.00        0.000000      0.076
# 1          0.173469             0.880         0.00        0.051471      0.098
# 2          0.173469             0.760         0.04        0.029412      0.092
# 3          0.520408             0.280         0.56        0.000000      0.075
# 5          0.132653             0.660         0.00        0.000000      0.075
# ...             ...               ...          ...             ...        ...
# 1593       0.071429             0.620         0.08        0.000000      0.068
# 1594       0.010204             0.600         0.08        0.007353      0.090
# 1595       0.000000             0.550         0.10        0.022059      0.067
# 1597       0.000000             0.645         0.12        0.007353      0.075
# 1598       0.000000             0.310         0.47        0.125000      0.067
#
# ...

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 5       5
#        ..
# 1593    6
# 1594    5
# 1595    6
# 1597    5
# 1598    6
# Name: quality, Length: 1359, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x, y, random_state=42,test_size=0.20, stratify=y)

#here strarity =y represent the table should   enables all the values of  y

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg_model = LogisticRegression()
logreg_model.fit(x_train, y_train)
y_pred = logreg_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
print('Accuracy: ', accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.6213235294117647

# %%
print('Precision: ', precision_score(y_test, y_pred, average='weighted'))
# Out:
# Precision:  0.6230355794737533

# %%
print('Recall: ', recall_score(y_test, y_pred, average='weighted'))
# Out:
# Recall:  0.6213235294117647

# %%
print('f1 score: ',f1_score(y_test, y_pred, average='weighted'))
# Out:
# f1 score:  0.5990553572221613

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[103,  25,   0],
#        [ 44,  60,   3],
#        [  2,  29,   6]])

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
metric_k = []
neighbors = np.arange(3, 50)

# %%
for k in neighbors:
  classifier = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
  classifier.fit(x_train, y_train)
  y_pred = classifier.predict(x_test)
  acc = accuracy_score(y_test, y_pred)
  metric_k.append(acc)

# %%
plt.plot(neighbors, metric_k, 'o-')
plt.xlabel('k value')
plt.ylabel('accuracy')
plt.grid()

# %%
classifier = KNeighborsClassifier(n_neighbors=25, metric='minkowski', p=2)
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)

# %%
print('Accuracy: ', accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.625

# %%
print('Precision: ', precision_score(y_test, y_pred, average='weighted'))
# Out:
# Precision:  0.6147442903876726

# %%
print('Recall: ', recall_score(y_test, y_pred, average='weighted'))
# Out:
# Recall:  0.625

# %%
print('f1 score: ',f1_score(y_test, y_pred, average='weighted'))
# Out:
# f1 score:  0.6128669998045745
